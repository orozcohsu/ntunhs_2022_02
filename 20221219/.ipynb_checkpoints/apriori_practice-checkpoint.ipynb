# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('retail.csv',low_memory=False)
data.head()
# Out:
#   InvoiceNo StockCode                                lower  ... UnitPrice  CustomerID         Country
# 0    536365    85123A   white hanging heart t-light holder  ...      2.55     17850.0  United Kingdom
# 1    536365     71053                  white metal lantern  ...      3.39     17850.0  United Kingdom
# 2    536365    84406B       cream cupid hearts coat hanger  ...      2.75     17850.0  United Kingdom
# 3    536365    84029G  knitted union flag hot water bottle  ...      3.39     17850.0  United Kingdom
# 4    536365    84029E       red woolly hottie white heart.  ...      3.39     17850.0  United Kingdom
#
# [5 rows x 9 columns]

# %%
#查看欄位
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'lower', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#查看所有Country
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
#清理資料空白
data['Description']=data['Description'].str.strip()

# %%
#清除遺缺值
data.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
#將InvoiceNo轉換為文字
data['InvoiceNo']=data['InvoiceNo'].astype('str')

# %%
#InvoiceNo有C字母的都刪除
data=data[~data['InvoiceNo'].str.contains('C')]

# %%
#在France消費的資料
basket_France=data[data['Country']=='France'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
#在United Kingdom消費的資料
basket_UK=data[data['Country']=='United Kingdom'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
#在Portugal消費的資料
basket_Por=data[data['Country']=='Portugal'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')
#在Sweden消費的資料
basket_Sweden=data[data['Country']=='Sweden'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
#編碼，讓數據值只有0或1
def hot_encode(x):
    if(x<= 0):
        return 0
    if(x>= 1):
        return 1

#需熟知applymap函數用法
basket_France =basket_France.applymap(hot_encode)
basket_UK = basket_UK.applymap(hot_encode)
basket_Por = basket_Por.applymap(hot_encode)
basket_Sweden = basket_Sweden.applymap(hot_encode)

# %%
basket_France
# Out:
# Description  10 COLOUR SPACEBOY PEN  ...  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo                            ...
# 536370                            0  ...                                0
# 536852                            0  ...                                0
# 536974                            0  ...                                0
# 537065                            0  ...                                0
# 537463                            0  ...                                0
# ...                             ...  ...                              ...
# 580986                            0  ...                                0
# 581001                            0  ...                                0
# 581171                            0  ...                                0
# 581279                            0  ...                                0
# 581587                            0  ...                                0
#
# [392 rows x 1563 columns]

# %%
#建立模型
#use_colnames為顯示事件名稱
#設定最小支持度(min_support)
frq_items = apriori(basket_France, min_support = 0.05, use_colnames = True)

# %%
#找出關聯規則
#metric預設為:confidence，但是有其他的選項: support,lift,leverage,conviction
#min_threshold:用來調整規則數量的多寡
#用?association_rules查看參數說明
rules = association_rules(frq_items, metric ="lift", min_threshold = 1.5)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules
# Out:
#                                            antecedents                               consequents  ...  leverage  conviction
# 156  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...           (SET/6 RED SPOTTY PAPER PLATES)  ...  0.086474   34.897959
# 158  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...             (SET/6 RED SPOTTY PAPER CUPS)  ...  0.085433   34.489796
# 186  (POSTAGE, SET/6 RED SPOTTY PAPER CUPS, SET/20 ...           (SET/6 RED SPOTTY PAPER PLATES)  ...  0.070895   28.790816
# 188  (POSTAGE, SET/20 RED RETROSPOT PAPER NAPKINS, ...             (SET/6 RED SPOTTY PAPER CUPS)  ...  0.070036   28.454082
# 67                     (SET/6 RED SPOTTY PAPER PLATES)             (SET/6 RED SPOTTY PAPER CUPS)  ...  0.104878   21.556122
# ..                                                 ...                                       ...  ...       ...         ...
# 55                     (RED TOADSTOOL LED NIGHT LIGHT)        (PLASTERS IN TIN WOODLAND ANIMALS)  ...  0.022614    1.177296
# 57                     (RED TOADSTOOL LED NIGHT LIGHT)                      (RABBIT NIGHT LIGHT)  ...  0.019380    1.151939
# 56                                (RABBIT NIGHT LIGHT)           (RED TOADSTOOL LED NIGHT LIGHT)  ...  0.019380    1.143338
# 131                    (RED TOADSTOOL LED NIGHT LIGHT)  (POSTAGE, PLASTERS IN TIN CIRCUS PARADE)  ...  0.024222    1.186174
# 49                     (RED TOADSTOOL LED NIGHT LIGHT)           (PLASTERS IN TIN CIRCUS PARADE)  ...  0.020525    1.157763
#
# [198 rows x 9 columns]

# %%
# ?association_rules
# Out:
# Signature:
# association_rules(
#     df,
#     metric='confidence',
#     min_threshold=0.8,
#     support_only=False,
# )
# Docstring:
# Generates a DataFrame of association rules including the
# metrics 'score', 'confidence', and 'lift'
#
# Parameters
# -----------
# df : pandas DataFrame
#   pandas DataFrame of frequent itemsets
#   with columns ['support', 'itemsets']
#
# metric : string (default: 'confidence')
#   Metric to evaluate if a rule is of interest.
#   **Automatically set to 'support' if `support_only=True`.**
#   Otherwise, supported metrics are 'support', 'confidence', 'lift',
#   'leverage', and 'conviction'
#   These metrics are computed as follows:
#
#   - support(A->C) = support(A+C) [aka 'support'], range: [0, 1]
#
#   - confidence(A->C) = support(A+C) / support(A), range: [0, 1]
#
#   - lift(A->C) = confidence(A->C) / support(C), range: [0, inf]
#
#   - leverage(A->C) = support(A->C) - support(A)*support(C),
#     range: [-1, 1]
#
#   - conviction = [1 - support(C)] / [1 - confidence(A->C)],
#     range: [0, inf]
#
#
# min_threshold : float (default: 0.8)
#   Minimal threshold for the evaluation metric,
#   via the `metric` parameter,
#   to decide whether a candidate rule is of interest.
#
# support_only : bool (default: False)
#   Only computes the rule support and fills the other
#   metric columns with NaNs. This is useful if:
#
#   a) the input DataFrame is incomplete, e.g., does
#   not contain support values for all rule antecedents
#   and consequents
#
#   b) you simply want to speed up the computation because
#   you don't need the other metrics.
#
# Returns
# ----------
# pandas DataFrame with columns "antecedents" and "consequents"
#   that store itemsets, plus the scoring metric columns:
#   "antecedent support", "consequent support",
#   "support", "confidence", "lift",
#   "leverage", "conviction"
#   of all rules for which
#   metric(rule) >= min_threshold.
#   Each entry in the "antecedents" and "consequents" columns are
#   of type `frozenset`, which is a Python built-in type that
#   behaves similarly to sets except that it is immutable
#   (For more info, see
#   https://docs.python.org/3.6/library/stdtypes.html#frozenset).
#
# Examples
# -----------
# For usage examples, please see
# http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/
# File:      c:\users\orozc\miniconda3\envs\20221024\lib\site-packages\mlxtend\frequent_patterns\association_rules.py
# Type:      function

# %%
#找出關聯規則
frq_items = apriori(basket_UK, min_support = 0.02, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence','lift'], ascending =[False, False])
rules.head()
# Out:
#                                            antecedents                        consequents  ...  leverage  conviction
# 166  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...  (GREEN REGENCY TEACUP AND SAUCER)  ...  0.024945    9.786461
# 164  (GREEN REGENCY TEACUP AND SAUCER, PINK REGENCY...  (ROSES REGENCY TEACUP AND SAUCER)  ...  0.024824    6.516911
# 27                    (PINK REGENCY TEACUP AND SAUCER)  (GREEN REGENCY TEACUP AND SAUCER)  ...  0.029024    5.300218
# 172  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)          (JUMBO BAG RED RETROSPOT)  ...  0.018887    4.525739
# 146                   (PINK REGENCY TEACUP AND SAUCER)  (ROSES REGENCY TEACUP AND SAUCER)  ...  0.027317    4.248161
#
# [5 rows x 9 columns]

# %%
#找出關聯規則
frq_items = apriori(basket_Por, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
#                               antecedents                         consequents  ...  leverage  conviction
# 1170     (SET 12 COLOUR PENCILS SPACEBOY)  (SET 12 COLOUR PENCILS DOLLY GIRL)  ...  0.049049         inf
# 1171   (SET 12 COLOUR PENCILS DOLLY GIRL)    (SET 12 COLOUR PENCILS SPACEBOY)  ...  0.049049         inf
# 1172   (SET OF 4 KNICK KNACK TINS LONDON)  (SET 12 COLOUR PENCILS DOLLY GIRL)  ...  0.049049         inf
# 1173   (SET 12 COLOUR PENCILS DOLLY GIRL)  (SET OF 4 KNICK KNACK TINS LONDON)  ...  0.049049         inf
# 1174  (SET OF 4 KNICK KNACK TINS POPPIES)  (SET 12 COLOUR PENCILS DOLLY GIRL)  ...  0.049049         inf
#
# [5 rows x 9 columns]

# %%
#找出關聯規則
frq_items = apriori(basket_Sweden, min_support = 0.05, use_colnames = True)
rules = association_rules(frq_items, metric ="lift", min_threshold = 1)
rules = rules.sort_values(['confidence', 'lift'], ascending =[False, False])
rules.head()
# Out:
#                            antecedents                     consequents  antecedent support  ...  lift  leverage  conviction
# 0        (12 PENCILS SMALL TUBE SKULL)   (PACK OF 72 SKULL CAKE CASES)            0.055556  ...  18.0  0.052469         inf
# 1        (PACK OF 72 SKULL CAKE CASES)   (12 PENCILS SMALL TUBE SKULL)            0.055556  ...  18.0  0.052469         inf
# 4              (36 DOILIES DOLLY GIRL)  (ASSORTED BOTTLE TOP  MAGNETS)            0.055556  ...  18.0  0.052469         inf
# 5       (ASSORTED BOTTLE TOP  MAGNETS)         (36 DOILIES DOLLY GIRL)            0.055556  ...  18.0  0.052469         inf
# 180  (CHILDRENS CUTLERY CIRCUS PARADE)  (CHILDRENS CUTLERY DOLLY GIRL)            0.055556  ...  18.0  0.052469         inf
#
# [5 rows x 9 columns]
